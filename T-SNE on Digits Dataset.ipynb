# %% [markdown]
# # Name- Abhinav Kumar

# %% [markdown]
# # PRN- 21070126006

# %% [markdown]
# # Branch- AIML_A1

# %% [raw]
# t-SNE is particularly useful for visualizing complex, nonlinear relationships in high-dimensional data, as it attempts to preserve the pairwise similarities between data points in the lower-dimensional embedding. It does this by modeling the high-dimensional data as a probability distribution, and then minimizing the Kullback-Leibler divergence between the high-dimensional and low-dimensional probability distributions. The resulting low-dimensional embedding can then be visualized using a scatter plot or other visualization technique.
#
# t-SNE has been successfully applied in a wide variety of domains, including computer vision, natural language processing, and bioinformatics, and has been used to visualize high-dimensional data such as images, text documents, and genomic data. However, it is important to note that t-SNE is a computationally expensive algorithm, and may not be suitable for very large datasets.

# %%
# Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.manifold import TSNE

# %%
# Load the MNIST dataset
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
# Run t-SNE on the data
tsne = TSNE(n_components=2, random_state=0)
X_tsne = tsne.fit_transform(X)

# %%
# Visualize the results
plt.figure(figsize=(10, 8))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap=plt.cm.get_cmap('jet', 10))
plt.colorbar(ticks=range(10))
plt.clim(-0.5, 9.5)
plt.show()

# %% [raw]
# When visualizing the t-SNE embeddings, we can observe clusters of points that are close to each other in the lower-dimensional space. These clusters represent groups of data points that are similar to each other in the high-dimensional space. The number and shape of the clusters depends on the underlying structure of the data, as well as the parameters used in the t-SNE algorithm.
